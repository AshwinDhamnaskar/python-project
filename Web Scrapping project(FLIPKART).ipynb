# %%
from flask import Flask , render_template, request ,jsonify

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as urReq

# %%
flipkart_url="https://www.flipkart.com/search?q=iphone+11"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone+11'

# %%
response_website=urReq(flipkart_url)

# %%
data_flipkart=response_website.read()

# %%
beautifyed_html  = bs(data_flipkart,"html.parser")

# %%
beautifyed_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox=beautifyed_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
bigbox[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone+11&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy
# ...

# %%
product6 = "https://www.flipkart.com/search?q=iphone+11" + bigbox[6].div.div.div.a["href"]

# %%
import requests

# %%
product66=requests.get(product6)

# %%
product6
# Out:
# 'https://www.flipkart.com/search?q=iphone+11/apple-iphone-11-red-64-gb/p/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=a5c0690c-afa0-47d2-85bd-4ebce0b12601.MOBFWQ6BYYV3FCU7.SEARCH&ppt=None&ppn=None&ssid=p96im0f9q80000001675327171778&qH=f6cdfdaa9f3c23f3'

# %%
product66.encoding='utf-8'

# %%
product6_page=bs(product66.text,"html.parser")

# %%
all_review=product6_page.find_all('div',{"class":"_16PBlm"})

# %%
len(all_review)
# Out:
# 11

# %%
all_review[5]
# Out:
# <div class="_16PBlm _3_IKGE"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Worth every penny</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Previously I was using one plus 3t it was a great phone <br/>And then I decided to upgrade I am stuck between Samsung s10 plus or iPhone 11 <br/>I have seen the specs and everything were good except the display it’s somewhere between 720-1080 and it’s not even an amoled it’s an LCD display <br/>But I decided to go with iPhone because I have never used an IOS device I have Been an android user from the past 9 years I ordered IPhone 11 (128gb) product red<br/>My experience after using 3 weeks <br/>1. The delivery ...</div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202001/bl
# ...

# %%
rating=all_review[5].div.div.div.div.text

# %%
rating
# Out:
# '5'

# %%
name=all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
name
# Out:
# 'Vamshi  Chakrala '

# %%
comment_header=all_review[5].div.div.div.p.text

# %%
comment_header
# Out:
# 'Worth every penny'

# %%
all_review[5].div.div.find_all('div',{'class' : ""})[0].div.text
# Out:
# 'Previously I was using one plus 3t it was a great phone And then I decided to upgrade I am stuck between Samsung s10 plus or iPhone 11 I have seen the specs and everything were good except the display it’s somewhere between 720-1080 and it’s not even an amoled it’s an LCD display But I decided to go with iPhone because I have never used an IOS device I have Been an android user from the past 9 years I ordered IPhone 11 (128gb) product redMy experience after using 3 weeks 1. The delivery ...'

# %%
all_review[5].div.find_all('p',{"class":"_2sc7ZR"})[1].text
# Out:
# 'Jan, 2020'

# %%
product6_page.find_all('div',{'class' : "_30jeq3 _16Jk6d"})[0].text
# Out:
# '₹42,999'

# %%
for i in all_review:
    price=product6_page.find_all('div',{'class' : "_30jeq3 _16Jk6d"})[0].text
    long_review=i.div.find_all('p',{"class":"_2sc7ZR"})[1].text
    comment_header=i.div.div.div.p.text
    name=i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
    rating=i.div.div.div.div.text
    long=i.div.find_all('div',{'class' : ""})[0].div.text
    print(name,rating,comment_header,long_review,price,long,"\n")
# Out:
# Flipkart Customer 5 Simply awesome Nov, 2020 ₹42,999 Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.
#
# Flipkart Customer 5 Perfect product! Jun, 2020 ₹42,999 Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .
#
# Manish Raghuvanshi 5 Best in the market! Apr, 2021 ₹42,999 Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7. Pros-Camera top class - Battery top performed -Chipset no need to say as apple kind -Security as you expect from apple - Display super bright industry leading colour   accuracy and super responsive -Build quality as expect from apple sturdy  premium durable beautiful stylish. -Os most stable os in smartphone industry Cons -No 5G-Display is not based on OLED technology -Charger headphones and 1 apple stic...
#
# ...
